# %%
import os
import pandas as pd
from autogluon.tabular import TabularPredictor
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error
from sklearn.preprocessing import MinMaxScaler
import numpy as np

china_wacc_file_path = 'Middle_EAST_WACC.xlsx'
china_wacc_data = pd.read_excel(china_wacc_file_path)

china_wacc_data.columns = china_wacc_data.columns.str.strip()  

print(china_wacc_data.columns)

china_wacc_data['Month'] = pd.to_datetime(china_wacc_data['Month'], format='%Y-%m')


projects = ['Onshore', 'Offshore', 'Nuclear', 'CCS', 'Coal', 'Gas', 'Solar', 'Hydro', 'Biomass']
energy_types = ['Coal Price', 'Gas Price', 'Oil Price']  


scaler = MinMaxScaler()
china_wacc_data[energy_types] = scaler.fit_transform(china_wacc_data[energy_types])

results = []

for energy_type in energy_types:
    for project in projects:
        target = project
        train_data = china_wacc_data[[energy_type, 'inflation rate', target]].dropna()  

        output_dir = 'AutogluonModels' 

        predictor = TabularPredictor(label=target, path=output_dir).fit(
            train_data,
            time_limit=600, 
            presets='best_quality',  
            hyperparameters={
                'GBM': {
                    'max_depth': 3,  
                    'learning_rate': 0.01, 
                    'num_boost_round': 100,  
                    'min_child_weight': 5  
                },
                'CAT': {
                    'depth': 3,  
                    'learning_rate': 0.01,  
                    'iterations': 100, 
                    'l2_leaf_reg': 20  
                },
                'NN_TORCH': {
                    'num_layers': 1,  
                    'hidden_size': 16, 
                    'dropout': 0.3 
                }
            },
            num_bag_folds=10,  
            keep_only_best=True,  
            auto_stack=True 
        )


        performance = predictor.evaluate(train_data)
        

        predictions = predictor.predict(train_data)
        mape = mean_absolute_percentage_error(train_data[target], predictions)
        mse = mean_squared_error(train_data[target], predictions)  
        rmse = np.sqrt(mse)  
        results.append({
            'Energy Type': energy_type,
            'Project': project,
            'R²': performance['r2'],
            'MAPE': mape,
            'RMSE': rmse
        })


results_df = pd.DataFrame(results)
results_df.to_csv('Middle_EAST_results.csv', index=False)


print(results_df)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="/Users/oushilin/Desktop/AutogluonModels"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.4.0
# Python Version:     3.11.4
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 25.0.0: Mon Aug 25 21:17:51 PDT 2025; root:xnu-12377.1.9~3/RELEASE_ARM64_T6020
# CPU Count:          10
# Memory Avail:       4.83 GB / 16.00 GB (30.2%)
# Disk Space Avail:   174.20 GB / 460.43 GB (37.8%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=10, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 150s of the 600s of remaining time (25%).
# 		Context path: "/Users/oushilin/Desktop/AutogluonModels/ds_sub_fit/sub_fit_ho"
# Index(['Month', 'Onshore', 'Offshore', 'Nuclear', 'CCS', 'Coal', 'Gas',
#        'Solar', 'Hydro', 'Biomass', 'Coal Price', 'Gas Price', 'Oil Price',
#        'inflation rate'],
#       dtype='object')
# Leaderboard on holdout data (DyStack):
#                  model  score_holdout  score_val              eval_metric  pred_time_test  pred_time_val  fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      LightGBM_BAG_L2      -0.002519  -0.003708  root_mean_squared_error        0.681349       0.009436  2.347934                 0.008184                0.002709           0.770131            2       True          4
# 1  WeightedEnsemble_L3      -0.002519  -0.003708  root_mean_squared_error        0.681794       0.009572  2.349732                 0.000445                0.000136           0.001798            3       True          6
# 2      LightGBM_BAG_L1      -0.002823  -0.004385  root_mean_squared_error        0.343144       0.003133  0.832955                 0.343144                0.003133           0.832955            1       True          1
# 3      CatBoost_BAG_L1      -0.002897  -0.004282  root_mean_squared_error        0.330021       0.003594  0.744848                 0.330021                0.003594           0.744848            1       True          2
# 4  WeightedEnsemble_L2      -0.002897  -0.004282  root_mean_squared_error        0.330840       0.003729  0.746622                 0.000819                0.000135           0.001774            2       True          3
# 5      CatBoost_BAG_L2      -0.002903  -0.004216  root_mean_squared_error        0.677021       0.011069  2.312667                 0.003856                0.004342           0.734864            2       True          5
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	23s	 = DyStack   runtime |	577s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 577s
# AutoGluon will save models to "/Users/oushilin/Desktop/AutogluonModels"
# Train Data Rows:    120
# Train Data Columns: 2
# Label Column:       Onshore
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    5753.36 MB
# 	Train Data (Original)  Memory Usage: 0.00 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 2 | ['Coal Price', 'inflation rate']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 2 | ['Coal Price', 'inflation rate']
# 	0.0s = Fit runtime
# 	2 features in original data used to generate 2 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.00 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.01s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'GBM': [{'max_depth': 3, 'learning_rate': 0.01, 'num_boost_round': 100, 'min_child_weight': 5}],
# 	'CAT': [{'depth': 3, 'learning_rate': 0.01, 'iterations': 100, 'l2_leaf_reg': 20}],
# 	'NN_TORCH': [{'num_layers': 1, 'hidden_size': 16, 'dropout': 0.3}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 3 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 384.63s of the 577.09s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	-0.004	 = Validation score   (-root_mean_squared_error)
# 	0.74s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 381.94s of the 574.40s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=7.83%)
# 	-0.0041	 = Validation score   (-root_mean_squared_error)
# 	0.69s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 379.00s of the 571.46s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	Warning: Exception caused NeuralNetTorch_BAG_L1 to fail during training... Skipping this model.
# 		ray::_ray_fit() (pid=28244, ip=127.0.0.1)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 446, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 237, in _fit
#     self._get_net(train_dataset, params=params)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 267, in _get_net
#     self.model = EmbedNet(
#                  ^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/torch_network_modules.py", line 28, in __init__
#     params = self._set_params(**kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: EmbedNet._set_params() got an unexpected keyword argument 'dropout'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2171, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2055, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 270, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 389, in _fit
#     self._fit_folds(
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 868, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 723, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 664, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 620, in _process_fold_results
#     raise processed_exception
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 583, in _process_fold_results
#     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
#                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/ray/_private/worker.py", line 2782, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/ray/_private/worker.py", line 929, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::_ray_fit() (pid=28244, ip=127.0.0.1)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 446, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 237, in _fit
#     self._get_net(train_dataset, params=params)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 267, in _get_net
#     self.model = EmbedNet(
#                  ^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/torch_network_modules.py", line 28, in __init__
#     params = self._set_params(**kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: EmbedNet._set_params() got an unexpected keyword argument 'dropout'
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 567.83s of remaining time.
# 	Ensemble Weights: {'LightGBM_BAG_L1': 0.857, 'CatBoost_BAG_L1': 0.143}
# 	-0.004	 = Validation score   (-root_mean_squared_error)
# 	0.0s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 3 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 567.82s of the 567.82s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	-0.0035	 = Validation score   (-root_mean_squared_error)
# 	0.75s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 565.20s of the 565.20s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=7.87%)
# 2025-09-30 21:48:36,096	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 21:48:36,097	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 21:48:36,097	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 21:48:36,098	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 21:48:36,099	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 21:48:36,100	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 21:48:36,101	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 21:48:36,103	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 21:48:36,104	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	-0.004	 = Validation score   (-root_mean_squared_error)
# 	0.61s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 562.24s of the 562.24s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	Warning: Exception caused NeuralNetTorch_BAG_L2 to fail during training... Skipping this model.
# 		ray::_ray_fit() (pid=28321, ip=127.0.0.1)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 446, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 237, in _fit
#     self._get_net(train_dataset, params=params)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 267, in _get_net
#     self.model = EmbedNet(
#                  ^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/torch_network_modules.py", line 28, in __init__
#     params = self._set_params(**kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: EmbedNet._set_params() got an unexpected keyword argument 'dropout'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2171, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2055, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 270, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 389, in _fit
#     self._fit_folds(
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 868, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 723, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 664, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 620, in _process_fold_results
#     raise processed_exception
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 583, in _process_fold_results
#     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
#                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/ray/_private/worker.py", line 2782, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/ray/_private/worker.py", line 929, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::_ray_fit() (pid=28321, ip=127.0.0.1)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 446, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 237, in _fit
#     self._get_net(train_dataset, params=params)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 267, in _get_net
#     self.model = EmbedNet(
#                  ^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/torch_network_modules.py", line 28, in __init__
#     params = self._set_params(**kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: EmbedNet._set_params() got an unexpected keyword argument 'dropout'
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the 558.62s of remaining time.
# 	Ensemble Weights: {'LightGBM_BAG_L2': 1.0}
# 	-0.0035	 = Validation score   (-root_mean_squared_error)
# 	0.0s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 18.5s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 1480.3 rows/s (12 batch size)
# Deleting model WeightedEnsemble_L2. All files under /Users/oushilin/Desktop/AutogluonModels/models/WeightedEnsemble_L2 will be removed.
# Deleting model CatBoost_BAG_L2. All files under /Users/oushilin/Desktop/AutogluonModels/models/CatBoost_BAG_L2 will be removed.
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/Users/oushilin/Desktop/AutogluonModels")
# Warning: path already exists! This predictor may overwrite an existing predictor! path="/Users/oushilin/Desktop/AutogluonModels"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.4.0
# Python Version:     3.11.4
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 25.0.0: Mon Aug 25 21:17:51 PDT 2025; root:xnu-12377.1.9~3/RELEASE_ARM64_T6020
# CPU Count:          10
# Memory Avail:       5.65 GB / 16.00 GB (35.3%)
# Disk Space Avail:   174.19 GB / 460.43 GB (37.8%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=10, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 150s of the 600s of remaining time (25%).
# 		Context path: "/Users/oushilin/Desktop/AutogluonModels/ds_sub_fit/sub_fit_ho"
# 2025-09-30 21:48:45,106	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 21:48:45,107	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 21:48:45,107	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 21:48:45,108	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 21:48:45,109	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 21:48:45,110	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 21:48:45,111	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 21:48:45,112	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 21:48:45,114	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# Leaderboard on holdout data (DyStack):
#                  model  score_holdout  score_val              eval_metric  pred_time_test  pred_time_val  fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      LightGBM_BAG_L2      -0.001815  -0.002915  root_mean_squared_error        0.725784       0.009219  2.270242                 0.009327                0.002421           0.821627            2       True          4
# 1  WeightedEnsemble_L3      -0.001815  -0.002915  root_mean_squared_error        0.726294       0.009346  2.271866                 0.000510                0.000127           0.001624            3       True          6
# 2      LightGBM_BAG_L1      -0.002326  -0.003223  root_mean_squared_error        0.362693       0.003343  0.770370                 0.362693                0.003343           0.770370            1       True          1
# 3  WeightedEnsemble_L2      -0.002326  -0.003223  root_mean_squared_error        0.363501       0.003470  0.772131                 0.000808                0.000128           0.001761            2       True          3
# 4      CatBoost_BAG_L2      -0.002390  -0.003233  root_mean_squared_error        0.720834       0.010514  2.098027                 0.004377                0.003716           0.649411            2       True          5
# 5      CatBoost_BAG_L1      -0.002486  -0.003294  root_mean_squared_error        0.353764       0.003455  0.678245                 0.353764                0.003455           0.678245            1       True          2
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	21s	 = DyStack   runtime |	579s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 579s
# AutoGluon will save models to "/Users/oushilin/Desktop/AutogluonModels"
# Train Data Rows:    120
# Train Data Columns: 2
# Label Column:       Offshore
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    5781.05 MB
# 	Train Data (Original)  Memory Usage: 0.00 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 2 | ['Coal Price', 'inflation rate']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 2 | ['Coal Price', 'inflation rate']
# 	0.0s = Fit runtime
# 	2 features in original data used to generate 2 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.00 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.01s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'GBM': [{'max_depth': 3, 'learning_rate': 0.01, 'num_boost_round': 100, 'min_child_weight': 5}],
# 	'CAT': [{'depth': 3, 'learning_rate': 0.01, 'iterations': 100, 'l2_leaf_reg': 20}],
# 	'NN_TORCH': [{'num_layers': 1, 'hidden_size': 16, 'dropout': 0.3}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 3 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 385.72s of the 578.73s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	-0.0029	 = Validation score   (-root_mean_squared_error)
# 	0.75s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 383.02s of the 576.02s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=7.78%)
# 	-0.0032	 = Validation score   (-root_mean_squared_error)
# 	0.66s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 380.06s of the 573.06s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	Warning: Exception caused NeuralNetTorch_BAG_L1 to fail during training... Skipping this model.
# 		ray::_ray_fit() (pid=28544, ip=127.0.0.1)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 446, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 237, in _fit
#     self._get_net(train_dataset, params=params)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 267, in _get_net
#     self.model = EmbedNet(
#                  ^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/torch_network_modules.py", line 28, in __init__
#     params = self._set_params(**kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: EmbedNet._set_params() got an unexpected keyword argument 'dropout'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2171, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2055, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 270, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 389, in _fit
#     self._fit_folds(
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 868, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 723, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 664, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 620, in _process_fold_results
#     raise processed_exception
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 583, in _process_fold_results
#     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
#                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/ray/_private/worker.py", line 2782, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/ray/_private/worker.py", line 929, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::_ray_fit() (pid=28544, ip=127.0.0.1)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 446, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 237, in _fit
#     self._get_net(train_dataset, params=params)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 267, in _get_net
#     self.model = EmbedNet(
#                  ^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/torch_network_modules.py", line 28, in __init__
#     params = self._set_params(**kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: EmbedNet._set_params() got an unexpected keyword argument 'dropout'
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 569.40s of remaining time.
# 	Ensemble Weights: {'LightGBM_BAG_L1': 1.0}
# 	-0.0029	 = Validation score   (-root_mean_squared_error)
# 	0.0s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 3 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 569.39s of the 569.39s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	-0.0026	 = Validation score   (-root_mean_squared_error)
# 	0.79s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 566.73s of the 566.73s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=7.78%)
# 2025-09-30 21:49:16,158	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 21:49:16,179	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 21:49:16,190	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 21:49:16,196	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 21:49:16,197	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 21:49:16,199	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 21:49:16,199	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 21:49:16,202	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 21:49:16,208	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	-0.0031	 = Validation score   (-root_mean_squared_error)
# 	0.68s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 563.79s of the 563.79s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	Warning: Exception caused NeuralNetTorch_BAG_L2 to fail during training... Skipping this model.
# 		ray::_ray_fit() (pid=28616, ip=127.0.0.1)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 446, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 237, in _fit
#     self._get_net(train_dataset, params=params)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 267, in _get_net
#     self.model = EmbedNet(
#                  ^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/torch_network_modules.py", line 28, in __init__
#     params = self._set_params(**kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: EmbedNet._set_params() got an unexpected keyword argument 'dropout'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2171, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2055, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 270, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 389, in _fit
#     self._fit_folds(
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 868, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 723, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 664, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 620, in _process_fold_results
#     raise processed_exception
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 583, in _process_fold_results
#     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
#                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/ray/_private/worker.py", line 2782, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/ray/_private/worker.py", line 929, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::_ray_fit() (pid=28616, ip=127.0.0.1)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 446, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 237, in _fit
#     self._get_net(train_dataset, params=params)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 267, in _get_net
#     self.model = EmbedNet(
#                  ^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/torch_network_modules.py", line 28, in __init__
#     params = self._set_params(**kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: EmbedNet._set_params() got an unexpected keyword argument 'dropout'
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the 560.33s of remaining time.
# 	Ensemble Weights: {'LightGBM_BAG_L2': 1.0}
# 	-0.0026	 = Validation score   (-root_mean_squared_error)
# 	0.0s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 18.42s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 1334.0 rows/s (12 batch size)
# Deleting model WeightedEnsemble_L2. All files under /Users/oushilin/Desktop/AutogluonModels/models/WeightedEnsemble_L2 will be removed.
# Deleting model CatBoost_BAG_L2. All files under /Users/oushilin/Desktop/AutogluonModels/models/CatBoost_BAG_L2 will be removed.
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/Users/oushilin/Desktop/AutogluonModels")
# Warning: path already exists! This predictor may overwrite an existing predictor! path="/Users/oushilin/Desktop/AutogluonModels"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.4.0
# Python Version:     3.11.4
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 25.0.0: Mon Aug 25 21:17:51 PDT 2025; root:xnu-12377.1.9~3/RELEASE_ARM64_T6020
# CPU Count:          10
# Memory Avail:       5.68 GB / 16.00 GB (35.5%)
# Disk Space Avail:   174.17 GB / 460.43 GB (37.8%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# ...
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 270, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 389, in _fit
#     self._fit_folds(
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 868, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 723, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 664, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 620, in _process_fold_results
#     raise processed_exception
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 583, in _process_fold_results
#     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
#                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/ray/_private/worker.py", line 2782, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/ray/_private/worker.py", line 929, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::_ray_fit() (pid=35990, ip=127.0.0.1)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 446, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 237, in _fit
#     self._get_net(train_dataset, params=params)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 267, in _get_net
#     self.model = EmbedNet(
#                  ^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/torch_network_modules.py", line 28, in __init__
#     params = self._set_params(**kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: EmbedNet._set_params() got an unexpected keyword argument 'dropout'
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 568.88s of remaining time.
# 	Ensemble Weights: {'LightGBM_BAG_L1': 0.8, 'CatBoost_BAG_L1': 0.2}
# 	-0.002	 = Validation score   (-root_mean_squared_error)
# 	0.0s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 3 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 568.87s of the 568.87s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	-0.0018	 = Validation score   (-root_mean_squared_error)
# 	0.72s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 566.14s of the 566.14s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=7.78%)
# 	-0.002	 = Validation score   (-root_mean_squared_error)
# 	0.67s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 563.15s of the 563.15s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=1, gpus=0, memory=0.00%)
# 2025-09-30 22:06:17,003	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 22:06:17,031	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 22:06:17,052	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 22:06:17,057	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 22:06:17,058	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 22:06:17,059	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 22:06:17,060	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 22:06:17,075	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-09-30 22:06:17,076	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	Warning: Exception caused NeuralNetTorch_BAG_L2 to fail during training... Skipping this model.
# 		ray::_ray_fit() (pid=36056, ip=127.0.0.1)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 446, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 237, in _fit
#     self._get_net(train_dataset, params=params)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 267, in _get_net
#     self.model = EmbedNet(
#                  ^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/torch_network_modules.py", line 28, in __init__
#     params = self._set_params(**kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: EmbedNet._set_params() got an unexpected keyword argument 'dropout'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2171, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2055, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 270, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 389, in _fit
#     self._fit_folds(
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 868, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 723, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 664, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 620, in _process_fold_results
#     raise processed_exception
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 583, in _process_fold_results
#     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
#                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/ray/_private/worker.py", line 2782, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/ray/_private/worker.py", line 929, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::_ray_fit() (pid=36056, ip=127.0.0.1)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 446, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 237, in _fit
#     self._get_net(train_dataset, params=params)
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 267, in _get_net
#     self.model = EmbedNet(
#                  ^^^^^^^^^
#   File "/Users/oushilin/anaconda3/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/torch_network_modules.py", line 28, in __init__
#     params = self._set_params(**kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: EmbedNet._set_params() got an unexpected keyword argument 'dropout'
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the 559.47s of remaining time.
# 	Ensemble Weights: {'LightGBM_BAG_L2': 1.0}
# 	-0.0018	 = Validation score   (-root_mean_squared_error)
# 	0.0s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 18.81s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 1200.5 rows/s (12 batch size)
# Deleting model WeightedEnsemble_L2. All files under /Users/oushilin/Desktop/AutogluonModels/models/WeightedEnsemble_L2 will be removed.
# Deleting model CatBoost_BAG_L2. All files under /Users/oushilin/Desktop/AutogluonModels/models/CatBoost_BAG_L2 will be removed.
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/Users/oushilin/Desktop/AutogluonModels")
#    Energy Type   Project        R²      MAPE      RMSE
# 0   Coal Price   Onshore  0.540160  0.030195  0.003426
# 1   Coal Price  Offshore  0.593177  0.025625  0.002467
# 2   Coal Price   Nuclear  0.541950  0.016570  0.001753
# 3   Coal Price       CCS  0.531644  0.017739  0.001861
# 4   Coal Price      Coal  0.541603  0.015588  0.001740
# 5   Coal Price       Gas  0.541603  0.022143  0.001740
# 6   Coal Price     Solar  0.575663  0.032321  0.003059
# 7   Coal Price     Hydro  0.542209  0.018198  0.001724
# 8   Coal Price   Biomass  0.541603  0.015588  0.001740
# 9    Gas Price   Onshore  0.537959  0.029698  0.003434
# 10   Gas Price  Offshore  0.613396  0.023242  0.002405
# 11   Gas Price   Nuclear  0.538070  0.016729  0.001761
# 12   Gas Price       CCS  0.525473  0.017911  0.001873
# 13   Gas Price      Coal  0.534054  0.015802  0.001755
# 14   Gas Price       Gas  0.534054  0.022450  0.001755
# 15   Gas Price     Solar  0.603539  0.030525  0.002957
# 16   Gas Price     Hydro  0.533545  0.018524  0.001741
# 17   Gas Price   Biomass  0.534054  0.015802  0.001755
# 18   Oil Price   Onshore  0.557071  0.028520  0.003362
# 19   Oil Price  Offshore  0.641803  0.022042  0.002315
# 20   Oil Price   Nuclear  0.547422  0.015791  0.001743
# 21   Oil Price       CCS  0.545335  0.016571  0.001834
# 22   Oil Price      Coal  0.547283  0.014960  0.001729
# 23   Oil Price       Gas  0.547282  0.021267  0.001729
# 24   Oil Price     Solar  0.647219  0.027262  0.002789
# 25   Oil Price     Hydro  0.547540  0.017611  0.001714
# 26   Oil Price   Biomass  0.547283  0.014960  0.001729
